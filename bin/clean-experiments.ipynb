# %%
import glob
import os
import shutil

# %%
for itd in glob.glob("/home/vsokolov/projects/timing-austin/experiments/Sim*/Austin_iteration_*/"):
    if os.path.isfile(itd + "finished"):
        omx = itd+'highway_skim_file.omx'
        if os.path.isfile(omx):
            print(omx)
            os.remove(omx)
        # os.remove(itd+'Austin-Supply.sqlite.tar.gz')
